# %%
import pandas as pd
import numpy as np
df=pd.read_csv('ISL DATASET A  - ISL DATASET A .csv')
df
# Out:
#                        PLAYER NAME                TEAM NAME  MATCHES PLAYED  \
# 0                DIMITROS PETRATOS  MOHUN BAGAN SUPER GIANT              35
# 1            JASON STEVEN CUMMINGS  MOHUN BAGAN SUPER GIANT              12
# 2                   ARMANDO SADIKU  MOHUN BAGAN SUPER GIANT              13
# 3                     MANVIR SINGH  MOHUN BAGAN SUPER GIANT             122
# 4                    LISTON COLACO  MOHUN BAGAN SUPER GIANT              87
# ..                             ...                      ...             ...
# 74              DANIEL LALHLIMPUIA                PUNJAB FC              60
# 75                     LUKA MAJCEN                PUNJAB FC              18
# 76  PRASANTH KARUTHADATHKUNI MOHAN                PUNJAB FC              86
# 77            RANJEET SINGH PANDRE                PUNJAB FC               3
# 78               WILMAR JORDÁN GIL                PUNJAB FC              22
#
# ...

# %%
# Drop rows with any null values
clean_df = df.dropna()

# Display the new DataFrame

clean_df = clean_df.drop(columns=['Potential'])
print(clean_df)
# Out:
#                  PLAYER NAME                TEAM NAME  MATCHES PLAYED  \
# 3               MANVIR SINGH  MOHUN BAGAN SUPER GIANT             122
# 4              LISTON COLACO  MOHUN BAGAN SUPER GIANT              87
# 11         NANDHAKUMAR SEKAR           EAST BENGAL FC              99
# 13     SUHAIR VADAKKEPEEDIKA           EAST BENGAL FC              64
# 15  VISHNU PUTHIYA VALAPPILL           EAST BENGAL FC              14
# 19              IRFAN YADWAD            CHENNAIYIN FC              12
# 21                 RAHIM ALI            CHENNAIYIN FC              66
# 22            VINCY BARRETTO            CHENNAIYIN FC              48
# 23        HALICHARAN NARZARY             BENGALURU FC             114
# 24             MONIRUL MOLLA             BENGALURU FC               6
# 26                ROHIT DANU             BENGALURU FC              43
# 28      SIVASAKTHI NARAYANAN             BENGALURU FC              42
# ...

# %%
clean_df.to_csv('Attacker_withOverall', index=False)
